# %%
import sys 
import os
sys.path.append('../')
from scripts.initialize_classes import Orchestrator
import subprocess

# %%
# Replace the following with URLS of EPL match from 24/25 season
os.environ['SS_URL'] = "https://www.sofascore.com/football/match/brentford-manchester-city/rsab#id:12436946"
os.environ['US_URL'] = "https://understat.com/match/26637"
orchestrator = Orchestrator()
orchestrator.run()
# Out:
# 2024/2025 EPL teams: 100%|██████████| 20/20 [00:25<00:00,  1.27s/it]
# 2024-09-27 11:29:21.364 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# No report generated
# 2024-09-27 11:29:21.554
# ...
#   command:
#
#     streamlit run /home/obli/.local/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-09-27 11:29:21.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-27 11:29:21.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-27 11:29:21.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-27 11:29:21.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# Command to run Streamlit
command = ["streamlit", "run", "../scripts/initialize_classes.py"]
proc = subprocess.Popen(command)
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://172.19.136.216:8502
#
# Running
# 2024/2025 EPL teams: 100%|██████████| 20/20 [00:25<00:00,  1.28s/it]
# No report generated
# 2024/2025 EPL teams: 100%|██████████| 20/20 [00:25<00:00,  1.29s/it]
# 2024-10-01 16:40:47.263 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/obli/.local/lib/python3.10/site-packages/urllib3/connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#   File "/home/obli/.local/lib/python3.10/site-packages/urllib3/connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#   File "/home/obli/.local/lib/python3.10/site-packages/urllib3/connection.py", line 464, in getresponse
#     httplib_response = super().getresponse()
#   File "/usr/lib/python3.10/http/client.py", line 1375, in getresponse
#     response.begin()
# ...

# %%
proc.terminate()
# Out:
#   Stopping...
